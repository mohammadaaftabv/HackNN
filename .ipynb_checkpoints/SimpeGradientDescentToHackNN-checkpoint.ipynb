# %%
import torch

#imports necessary to define a neural network 
import torch.nn as nn
import torch.nn.functional as F

#ensure you are using GPU.
if torch.cuda.is_available():  
  dev = "cuda:0" 
else:  
  dev = "cpu"  

device = torch.device(dev)
print(device)

dtype = torch.cuda.FloatTensor
import numpy as np
import torchvision
import matplotlib.pyplot as plt
from time import time
from torchvision import datasets, transforms
from torch import nn, optim
# Out:
# cuda:0

# %%
transform = transforms.Compose([transforms.ToTensor(),
                               transforms.Normalize(-0.5,0.5)])

# %%
trainset = datasets.MNIST('PATH_TO_STORE_TRAINSET', download=True, train=True, transform=transform)
valset = datasets.MNIST('PATH_TO_STORE_TESTSET', download=True, train=False, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=64, shuffle=True)
# Out:
# /home/mohammad/anaconda3/lib/python3.8/site-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1631630815121/work/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
dataiter = iter(trainloader)
images, labels = dataiter.next()

print(images.shape)
print(labels.shape)
# Out:
# torch.Size([64, 1, 28, 28])
# torch.Size([64])

# %%
figure = plt.figure()
num_of_images = 60
for index in range(1, num_of_images + 1):
    plt.subplot(6, 10, index)
    plt.axis('off')
    plt.imshow(images[index].numpy().squeeze(), cmap='gray_r')

# %%
input_size = 784
hidden_sizes = [128, 64]
output_size = 10

model = nn.Sequential(nn.Linear(input_size, hidden_sizes[0]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[0], hidden_sizes[1]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[1], output_size),
                      nn.LogSoftmax()).cuda()
model.to(device)
print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=64, out_features=10, bias=True)
#   (5): LogSoftmax(dim=None)
# )

# %%
criterion = nn.NLLLoss()
images, labels = next(iter(trainloader))
images = images.view(images.shape[0], -1)

logps = model(images.cuda()) #log probabilities
loss = criterion(logps, labels.cuda()) #calculate the NLL loss
# Out:
# /home/mohammad/anaconda3/lib/python3.8/site-packages/torch/nn/modules/container.py:139: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)

# %%
optimizer = optim.SGD(model.parameters(), lr=0.003, momentum=0.9)
time0 = time()
epochs = 15
for e in range(epochs):
    running_loss = 0
    for images, labels in trainloader:
        # Flatten MNIST images into a 784 long vector
        images = images.view(images.shape[0], -1)
    
        # Training pass
        optimizer.zero_grad()
        
        output = model(images.cuda())
        loss = criterion(output, labels.cuda())
        
        #This is where the model learns by backpropagating
        loss.backward()
        
        #And optimizes its weights here
        optimizer.step()
        
        running_loss += loss.item()
    else:
        print("Epoch {} - Training loss: {}".format(e, running_loss/len(trainloader)))
        print("\nTraining Time (in minutes) =",(time()-time0)/60)
# Out:
# Epoch 0 - Training loss: 0.6754242070575258
#
# Training Time (in minutes) = 0.08855315446853637
# Epoch 1 - Training loss: 0.3123617999350974
#
# Training Time (in minutes) = 0.17674050331115723
# Epoch 2 - Training loss: 0.2551046397878544
#
# Training Time (in minutes) = 0.2641189614931742
# Epoch 3 - Training loss: 0.21426205731419992
#
# Training Time (in minutes) = 0.35431706508000693
# Epoch 4 - Training loss: 0.18239257441781986
#
# Training Time (in minutes) = 0.4451575001080831
# Epoch 5 - Training loss: 0.16066291097845478
#
# Training Time (in minutes) = 0.5367178956667582
# Epoch 6 - Training loss: 0.14344413600750824
#
# Training Time (in minutes) = 0.6261685967445374
# Epoch 7 - Training loss: 0.1276675291907495
#
# Training Time (in minutes) = 0.7154975533485413
# Epoch 8 - Training loss: 0.11775974307441588
#
# Training Time (in minutes) = 0.8065610527992249
# Epoch 9 - Training loss: 0.10924177720193574
#
# Training Time (in minutes) = 0.8952746868133545
# Epoch 10 - Training loss: 0.10042298259412143
#
# Training Time (in minutes) = 0.9840044021606446
# Epoch 11 - Training loss: 0.0951711851190021
#
# Training Time (in minutes) = 1.0749271392822266
# Epoch 12 - Training loss: 0.09067147146852841
#
# Training Time (in minutes) = 1.1636948823928832
# Epoch 13 - Training loss: 0.08523376597744871
#
# Training Time (in minutes) = 1.2540929476420084
# Epoch 14 - Training loss: 0.07649666047506114
#
# Training Time (in minutes) = 1.3444865783055624

# %%
def view_classify(img, ps):
    ''' Function for viewing an image and it's predicted classes.
    '''
    ps = ps.cpu().data.numpy().squeeze()

    fig, (ax1, ax2) = plt.subplots(figsize=(6,9), ncols=2)
    ax1.imshow(img.resize_(1, 28, 28).numpy().squeeze())
    ax1.axis('off')
    ax2.barh(np.arange(10), ps)
    ax2.set_aspect(0.1)
    ax2.set_yticks(np.arange(10))
    ax2.set_yticklabels(np.arange(10))
    ax2.set_title('Class Probability')
    ax2.set_xlim(0, 1.1)
    plt.tight_layout()
images, labels = next(iter(valloader))

img = images[0].view(1, 784) 
with torch.no_grad():
    logps = model(img.cuda())

ps = torch.exp(logps)
probab = list(ps.detach().cpu().numpy()[0])
print("Predicted Digit =", probab.index(max(probab)))
view_classify(img.view(1, 28, 28), ps)
# Out:
# Predicted Digit = 4

# %%
torch.exp(model(img.cuda()))
# Out:
# tensor([[2.0544e-07, 1.0196e-08, 3.2381e-01, 1.8096e-06, 6.7619e-01, 7.0030e-07,
#          3.7915e-07, 2.1206e-06, 2.4849e-10, 1.9402e-06]], device='cuda:0',
#        grad_fn=<ExpBackward>)

# %%
correct_count, all_count = 0, 0
for images,labels in valloader:
  for i in range(len(labels)):
    img = images[i].view(1, 784)
    with torch.no_grad():
        logps = model(img.cuda())

    
    ps = torch.exp(logps)
    probab = list(ps.detach().cpu().numpy()[0])
    pred_label = probab.index(max(probab))
    true_label = labels.numpy()[i]
    if(true_label == pred_label):
      correct_count += 1
    all_count += 1

print("Number Of Images Tested =", all_count)
print("\nModel Accuracy =", (correct_count/all_count))
# Out:
# Number Of Images Tested = 10000
#
# Model Accuracy = 0.9733

# %%
images.shape
# Out:
# torch.Size([16, 1, 28, 28])

# %%
img=images[1].reshape([1,784])
print(img.shape)

print(torch.exp(model(img.cuda())))
plt.imshow(img.numpy().reshape(28,28))
# Out:
# torch.Size([1, 784])
# tensor([[9.9901e-01, 1.6192e-09, 2.6767e-04, 7.1236e-06, 5.5416e-08, 3.4717e-05,
#          2.2412e-06, 4.1534e-06, 4.4584e-05, 6.2518e-04]], device='cuda:0',
#        grad_fn=<ExpBackward>)

# %%
def findloss(diff,pred):
    
#     diff is array of noise
#     pred is the prediction of the above trained model
    
    
    l1=(torch.square(diff))
    l1=torch.mean(l1)
    
    l2=pred**(-1)
    
    fl=l1+l2
    fl=fl**0.5
    
    return fl

# %%
diff=torch.rand(784).cuda().requires_grad_()

# %%
learning_rate=0.0005
num_descents=2000000 #number of times gradient descent is employed

img=img.cuda()

for i in range(num_descents):
    
    imagef=img+diff
    pred=torch.exp(model(imagef.reshape([1,784])))[0][8]
    
    totalloss=findloss(diff,pred)
    if i%10000 ==0:
        print('Loss and prediction by the model after '+str(i)+' steps of gradient descent are '+str(totalloss.item()),str(pred.item()))
     
        
    #find gradients of totalt wrt yarray.
    totalloss.backward()

    gradients=diff.grad
    #torch.clip(gradients,max=100.0)
    with torch.no_grad():
        diff[1:]=diff[1:]-learning_rate*gradients[1:]
    diff.grad.data.zero_()
# Out:
# Loss and prediction by the model after 0 steps of gradient descent are 363.3811950683594 7.573144557682099e-06
# Loss and prediction by the model after 10000 steps of gradient descent are 1.2008347511291504 0.9240403771400452
# Loss and prediction by the model after 20000 steps of gradient descent are 1.1843360662460327 0.9577853083610535
# Loss and prediction by the model after 30000 steps of gradient descent are 1.1774511337280273 0.9708487391471863
# Loss and prediction by the model after 40000 steps of gradient descent are 1.173469066619873 0.977227509021759
# Loss and prediction by the model after 50000 steps of gradient descent are 1.1705348491668701 0.9810954332351685
# Loss and prediction by the model after 60000 steps of gradient descent are 1.1681134700775146 0.9836969375610352
# Loss and prediction by the model after 70000 steps of gradient descent are 1.1658486127853394 0.9859054684638977
# Loss and prediction by the model after 80000 steps of gradient descent are 1.1637074947357178 0.9878293871879578
# Loss and prediction by the model after 90000 steps of gradient descent are 1.1617757081985474 0.9892033338546753
# Loss and prediction by the model after 100000 steps of gradient descent are 1.159981369972229 0.9902337789535522
# Loss and prediction by the model after 110000 steps of gradient descent are 1.1582814455032349 0.991037905216217
# Loss and prediction by the model after 120000 steps of gradient descent are 1.1566463708877563 0.991672694683075
# Loss and prediction by the model after 130000 steps of gradient descent are 1.1550571918487549 0.9921960234642029
# Loss and prediction by the model after 140000 steps of gradient descent are 1.153503179550171 0.992624044418335
# Loss and prediction by the model after 150000 steps of gradient descent are 1.1519827842712402 0.9929894208908081
# Loss and prediction by the model after 160000 steps of gradient descent are 1.1504918336868286 0.9933040738105774
# Loss and prediction by the model after 170000 steps of gradient descent are 1.1490219831466675 0.9935638308525085
# Loss and prediction by the model after 180000 steps of gradient descent are 1.1475732326507568 0.9937871098518372
# Loss and prediction by the model after 190000 steps of gradient descent are 1.1461443901062012 0.9939889311790466
# Loss and prediction by the model after 200000 steps of gradient descent are 1.1447347402572632 0.9941684603691101
# Loss and prediction by the model after 210000 steps of gradient descent are 1.1433439254760742 0.9943250417709351
# Loss and prediction by the model after 220000 steps of gradient descent are 1.1419681310653687 0.9944643974304199
# Loss and prediction by the model after 230000 steps of gradient descent are 1.140608787536621 0.9945903420448303
# Loss and prediction by the model after 240000 steps of gradient descent are 1.1392651796340942 0.9947053790092468
# Loss and prediction by the model after 250000 steps of gradient descent are 1.137938141822815 0.9948098659515381
# Loss and prediction by the model after 260000 steps of gradient descent are 1.1366244554519653 0.9949063062667847
# Loss and prediction by the model after 270000 steps of gradient descent are 1.1353237628936768 0.9949943423271179
# Loss and prediction by the model after 280000 steps of gradient descent are 1.134035587310791 0.9950730204582214
# Loss and prediction by the model after 290000 steps of gradient descent are 1.1327587366104126 0.9951426386833191
# Loss and prediction by the model after 300000 steps of gradient descent are 1.1314932107925415 0.9952057003974915
# Loss and prediction by the model after 310000 steps of gradient descent are 1.1302393674850464 0.995262622833252
# Loss and prediction by the model after 320000 steps of gradient descent are 1.128997802734375 0.9953147768974304
# Loss and prediction by the model after 330000 steps of gradient descent are 1.1277673244476318 0.9953641891479492
# Loss and prediction by the model after 340000 steps of gradient descent are 1.1265490055084229 0.9954097867012024
# Loss and prediction by the model after 350000 steps of gradient descent are 1.1253414154052734 0.9954517483711243
# Loss and prediction by the model after 360000 steps of gradient descent are 1.1241469383239746 0.9954886436462402
# Loss and prediction by the model after 370000 steps of gradient descent are 1.1229652166366577 0.9955230355262756
# Loss and prediction by the model after 380000 steps of gradient descent are 1.1217963695526123 0.9955546259880066
# Loss and prediction by the model after 390000 steps of gradient descent are 1.1206353902816772 0.9955853223800659
# Loss and prediction by the model after 400000 steps of gradient descent are 1.119483232498169 0.9956158995628357
# Loss and prediction by the model after 410000 steps of gradient descent are 1.118342638015747 0.9956448674201965
# Loss and prediction by the model after 420000 steps of gradient descent are 1.117214322090149 0.9956710338592529
# Loss and prediction by the model after 430000 steps of gradient descent are 1.116097331047058 0.995694637298584
# Loss and prediction by the model after 440000 steps of gradient descent are 1.1149914264678955 0.9957162737846375
# Loss and prediction by the model after 450000 steps of gradient descent are 1.1138979196548462 0.9957364201545715
# Loss and prediction by the model after 460000 steps of gradient descent are 1.1128151416778564 0.9957555532455444
# Loss and prediction by the model after 470000 steps of gradient descent are 1.1117420196533203 0.9957727193832397
# Loss and prediction by the model after 480000 steps of gradient descent are 1.1106795072555542 0.995789110660553
# Loss and prediction by the model after 490000 steps of gradient descent are 1.1096266508102417 0.9958048462867737
# Loss and prediction by the model after 500000 steps of gradient descent are 1.1085840463638306 0.9958191514015198
# Loss and prediction by the model after 510000 steps of gradient descent are 1.107550024986267 0.9958329796791077
# Loss and prediction by the model after 520000 steps of gradient descent are 1.1065268516540527 0.9958451390266418
# Loss and prediction by the model after 530000 steps of gradient descent are 1.1055134534835815 0.9958564639091492
# Loss and prediction by the model after 540000 steps of gradient descent are 1.1045106649398804 0.9958658218383789
# Loss and prediction by the model after 550000 steps of gradient descent are 1.1035196781158447 0.9958682656288147
# Loss and prediction by the model after 560000 steps of gradient descent are 1.102538824081421 0.9958695769309998
# Loss and prediction by the model after 570000 steps of gradient descent are 1.1015690565109253 0.9958717226982117
# Loss and prediction by the model after 580000 steps of gradient descent are 1.1006101369857788 0.9958741664886475
# Loss and prediction by the model after 590000 steps of gradient descent are 1.0996605157852173 0.9958755970001221
# Loss and prediction by the model after 600000 steps of gradient descent are 1.0987200736999512 0.9958765506744385
# Loss and prediction by the model after 610000 steps of gradient descent are 1.0977888107299805 0.9958778619766235
# Loss and prediction by the model after 620000 steps of gradient descent are 1.0968670845031738 0.995879590511322
# Loss and prediction by the model after 630000 steps of gradient descent are 1.0959535837173462 0.9958810210227966
# Loss and prediction by the model after 640000 steps of gradient descent are 1.0950504541397095 0.995883584022522
# Loss and prediction by the model after 650000 steps of gradient descent are 1.0941569805145264 0.9958850741386414
# Loss and prediction by the model after 660000 steps of gradient descent are 1.0932732820510864 0.9958869218826294
# Loss and prediction by the model after 670000 steps of gradient descent are 1.0923997163772583 0.9958890676498413
# Loss and prediction by the model after 680000 steps of gradient descent are 1.0915364027023315 0.995891809463501
# Loss and prediction by the model after 690000 steps of gradient descent are 1.0906813144683838 0.9958938360214233
# Loss and prediction by the model after 700000 steps of gradient descent are 1.089834213256836 0.9958949089050293
# Loss and prediction by the model after 710000 steps of gradient descent are 1.0889958143234253 0.995895266532898
# Loss and prediction by the model after 720000 steps of gradient descent are 1.0881662368774414 0.9958963990211487
# Loss and prediction by the model after 730000 steps of gradient descent are 1.0873453617095947 0.995897650718689
# Loss and prediction by the model after 740000 steps of gradient descent are 1.086532711982727 0.9958980679512024
# Loss and prediction by the model after 750000 steps of gradient descent are 1.0857278108596802 0.9958980679512024
# Loss and prediction by the model after 760000 steps of gradient descent are 1.0849312543869019 0.9958983063697815
# Loss and prediction by the model after 770000 steps of gradient descent are 1.0841422080993652 0.9958957433700562
# Loss and prediction by the model after 780000 steps of gradient descent are 1.0833609104156494 0.9958916902542114
# Loss and prediction by the model after 790000 steps of gradient descent are 1.08258855342865 0.9958873391151428
# Loss and prediction by the model after 800000 steps of gradient descent are 1.0818248987197876 0.9958829283714294
# Loss and prediction by the model after 810000 steps of gradient descent are 1.0810695886611938 0.9958808422088623
# Loss and prediction by the model after 820000 steps of gradient descent are 1.0803215503692627 0.9958788156509399
# Loss and prediction by the model after 830000 steps of gradient descent are 1.0795811414718628 0.9958771467208862
# Loss and prediction by the model after 840000 steps of gradient descent are 1.078849196434021 0.9958760738372803
# Loss and prediction by the model after 850000 steps of gradient descent are 1.0781253576278687 0.9958765506744385
# Loss and prediction by the model after 860000 steps of gradient descent are 1.0774086713790894 0.9958775043487549
# Loss and prediction by the model after 870000 steps of gradient descent are 1.0766990184783936 0.995878279209137
# Loss and prediction by the model after 880000 steps of gradient descent are 1.0759974718093872 0.9958788156509399
# Loss and prediction by the model after 890000 steps of gradient descent are 1.0753047466278076 0.9958808422088623
# Loss and prediction by the model after 900000 steps of gradient descent are 1.0746196508407593 0.9958829283714294
# Loss and prediction by the model after 910000 steps of gradient descent are 1.07394278049469 0.9958860278129578
# Loss and prediction by the model after 920000 steps of gradient descent are 1.073272705078125 0.9958890080451965
# Loss and prediction by the model after 930000 steps of gradient descent are 1.0726102590560913 0.9958927631378174
# Loss and prediction by the model after 940000 steps of gradient descent are 1.0719547271728516 0.9958968758583069
# Loss and prediction by the model after 950000 steps of gradient descent are 1.0713058710098267 0.9959012866020203
# Loss and prediction by the model after 960000 steps of gradient descent are 1.0706641674041748 0.9959067106246948
# Loss and prediction by the model after 970000 steps of gradient descent are 1.070029854774475 0.9959117770195007
# Loss and prediction by the model after 980000 steps of gradient descent are 1.0694012641906738 0.9959164261817932
# Loss and prediction by the model after 990000 steps of gradient descent are 1.0687788724899292 0.9959213137626648
# Loss and prediction by the model after 1000000 steps of gradient descent are 1.068163275718689 0.9959276914596558
# Loss and prediction by the model after 1010000 steps of gradient descent are 1.0675591230392456 0.9959281086921692
# Loss and prediction by the model after 1020000 steps of gradient descent are 1.0669642686843872 0.9959247708320618
# Loss and prediction by the model after 1030000 steps of gradient descent are 1.0663765668869019 0.9959216117858887
# Loss and prediction by the model after 1040000 steps of gradient descent are 1.0657963752746582 0.9959185123443604
# Loss and prediction by the model after 1050000 steps of gradient descent are 1.0652230978012085 0.9959182739257812
# Loss and prediction by the model after 1060000 steps of gradient descent are 1.0646549463272095 0.9959182739257812
# Loss and prediction by the model after 1070000 steps of gradient descent are 1.0640933513641357 0.9959192872047424
# Loss and prediction by the model after 1080000 steps of gradient descent are 1.0635383129119873 0.9959201812744141
# Loss and prediction by the model after 1090000 steps of gradient descent are 1.06298828125 0.9959209561347961
# Loss and prediction by the model after 1100000 steps of gradient descent are 1.0624436140060425 0.995923638343811
# Loss and prediction by the model after 1110000 steps of gradient descent are 1.0619044303894043 0.9959267973899841
# Loss and prediction by the model after 1120000 steps of gradient descent are 1.0613715648651123 0.9959294199943542
# Loss and prediction by the model after 1130000 steps of gradient descent are 1.060844898223877 0.9959362149238586
# Loss and prediction by the model after 1140000 steps of gradient descent are 1.0603241920471191 0.9959450960159302
# Loss and prediction by the model after 1150000 steps of gradient descent are 1.0598090887069702 0.9959537386894226
# Loss and prediction by the model after 1160000 steps of gradient descent are 1.0592998266220093 0.9959620833396912
# Loss and prediction by the model after 1170000 steps of gradient descent are 1.058796763420105 0.9959700703620911
# Loss and prediction by the model after 1180000 steps of gradient descent are 1.0582985877990723 0.9959778785705566
# Loss and prediction by the model after 1190000 steps of gradient descent are 1.0578052997589111 0.995985209941864
# Loss and prediction by the model after 1200000 steps of gradient descent are 1.0573174953460693 0.9959917068481445
# Loss and prediction by the model after 1210000 steps of gradient descent are 1.0568352937698364 0.9959977865219116
# Loss and prediction by the model after 1220000 steps of gradient descent are 1.0563583374023438 0.9960034489631653
# Loss and prediction by the model after 1230000 steps of gradient descent are 1.055886149406433 0.9960087537765503
# Loss and prediction by the model after 1240000 steps of gradient descent are 1.0554193258285522 0.9960141181945801
# Loss and prediction by the model after 1250000 steps of gradient descent are 1.054958462715149 0.9960190057754517
# Loss and prediction by the model after 1260000 steps of gradient descent are 1.0545029640197754 0.9960240721702576
# Loss and prediction by the model after 1270000 steps of gradient descent are 1.0540528297424316 0.9960288405418396
# Loss and prediction by the model after 1280000 steps of gradient descent are 1.0536079406738281 0.9960334897041321
# Loss and prediction by the model after 1290000 steps of gradient descent are 1.0531684160232544 0.9960381984710693
# Loss and prediction by the model after 1300000 steps of gradient descent are 1.0527337789535522 0.996042788028717
# Loss and prediction by the model after 1310000 steps of gradient descent are 1.0523035526275635 0.9960470795631409
# Loss and prediction by the model after 1320000 steps of gradient descent are 1.0518778562545776 0.9960511922836304
# Loss and prediction by the model after 1330000 steps of gradient descent are 1.0514570474624634 0.9960554838180542
# Loss and prediction by the model after 1340000 steps of gradient descent are 1.0510408878326416 0.9960595965385437
# Loss and prediction by the model after 1350000 steps of gradient descent are 1.0506293773651123 0.9960635304450989
# Loss and prediction by the model after 1360000 steps of gradient descent are 1.0502225160598755 0.9960675239562988
# Loss and prediction by the model after 1370000 steps of gradient descent are 1.0498199462890625 0.9960709810256958
# Loss and prediction by the model after 1380000 steps of gradient descent are 1.0494216680526733 0.9960736036300659
# Loss and prediction by the model after 1390000 steps of gradient descent are 1.0490278005599976 0.9960760474205017
# Loss and prediction by the model after 1400000 steps of gradient descent are 1.0486385822296143 0.9960788488388062
# Loss and prediction by the model after 1410000 steps of gradient descent are 1.048254132270813 0.9960822463035583
# Loss and prediction by the model after 1420000 steps of gradient descent are 1.0478743314743042 0.9960853457450867
# Loss and prediction by the model after 1430000 steps of gradient descent are 1.0474995374679565 0.9960885047912598
# Loss and prediction by the model after 1440000 steps of gradient descent are 1.047128677368164 0.9960917234420776
# Loss and prediction by the model after 1450000 steps of gradient descent are 1.0467630624771118 0.9960956573486328
# Loss and prediction by the model after 1460000 steps of gradient descent are 1.0464023351669312 0.9960994124412537
# Loss and prediction by the model after 1470000 steps of gradient descent are 1.0460457801818848 0.9961032271385193
# Loss and prediction by the model after 1480000 steps of gradient descent are 1.0456925630569458 0.9961075186729431
# Loss and prediction by the model after 1490000 steps of gradient descent are 1.0453431606292725 0.9961109757423401
# Loss and prediction by the model after 1500000 steps of gradient descent are 1.0449978113174438 0.9961137771606445
# Loss and prediction by the model after 1510000 steps of gradient descent are 1.0446562767028809 0.9961172342300415
# Loss and prediction by the model after 1520000 steps of gradient descent are 1.044318437576294 0.9961209297180176
# Loss and prediction by the model after 1530000 steps of gradient descent are 1.0439846515655518 0.996124267578125
# Loss and prediction by the model after 1540000 steps of gradient descent are 1.0436546802520752 0.9961280822753906
# Loss and prediction by the model after 1550000 steps of gradient descent are 1.0433284044265747 0.9961321353912354
# Loss and prediction by the model after 1560000 steps of gradient descent are 1.0430058240890503 0.9961358904838562
# Loss and prediction by the model after 1570000 steps of gradient descent are 1.0426868200302124 0.9961397051811218
# Loss and prediction by the model after 1580000 steps of gradient descent are 1.042371153831482 0.9961431622505188
# Loss and prediction by the model after 1590000 steps of gradient descent are 1.0420588254928589 0.9961462616920471
# Loss and prediction by the model after 1600000 steps of gradient descent are 1.0417503118515015 0.9961494207382202
# Loss and prediction by the model after 1610000 steps of gradient descent are 1.0414456129074097 0.9961523413658142
# Loss and prediction by the model after 1620000 steps of gradient descent are 1.041144847869873 0.996155321598053
# Loss and prediction by the model after 1630000 steps of gradient descent are 1.0408480167388916 0.9961580634117126
# Loss and prediction by the model after 1640000 steps of gradient descent are 1.0405547618865967 0.9961607456207275
# Loss and prediction by the model after 1650000 steps of gradient descent are 1.0402650833129883 0.9961640238761902
# Loss and prediction by the model after 1660000 steps of gradient descent are 1.0399792194366455 0.9961667656898499
# Loss and prediction by the model after 1670000 steps of gradient descent are 1.0396966934204102 0.99616938829422
# Loss and prediction by the model after 1680000 steps of gradient descent are 1.0394175052642822 0.9961715340614319
# Loss and prediction by the model after 1690000 steps of gradient descent are 1.039141058921814 0.9961732625961304
# Loss and prediction by the model after 1700000 steps of gradient descent are 1.0388681888580322 0.9961749315261841
# Loss and prediction by the model after 1710000 steps of gradient descent are 1.0385980606079102 0.9961767792701721
# Loss and prediction by the model after 1720000 steps of gradient descent are 1.0383310317993164 0.9961786270141602
# Loss and prediction by the model after 1730000 steps of gradient descent are 1.0380668640136719 0.996180534362793
# Loss and prediction by the model after 1740000 steps of gradient descent are 1.037805438041687 0.996182382106781
# Loss and prediction by the model after 1750000 steps of gradient descent are 1.037546992301941 0.9961841106414795
# Loss and prediction by the model after 1760000 steps of gradient descent are 1.0372916460037231 0.9961857199668884
# Loss and prediction by the model after 1770000 steps of gradient descent are 1.0370391607284546 0.9961878657341003
# Loss and prediction by the model after 1780000 steps of gradient descent are 1.0367900133132935 0.9961894750595093
# Loss and prediction by the model after 1790000 steps of gradient descent are 1.036543369293213 0.9961913824081421
# Loss and prediction by the model after 1800000 steps of gradient descent are 1.0362995862960815 0.9961930513381958
# Loss and prediction by the model after 1810000 steps of gradient descent are 1.0360585451126099 0.9961948394775391
# Loss and prediction by the model after 1820000 steps of gradient descent are 1.0358202457427979 0.9961965084075928
# Loss and prediction by the model after 1830000 steps of gradient descent are 1.0355849266052246 0.9961980581283569
# Loss and prediction by the model after 1840000 steps of gradient descent are 1.035352349281311 0.9961996674537659
# Loss and prediction by the model after 1850000 steps of gradient descent are 1.035122275352478 0.9962013959884644
# Loss and prediction by the model after 1860000 steps of gradient descent are 1.0348953008651733 0.9962030053138733
# Loss and prediction by the model after 1870000 steps of gradient descent are 1.0346711874008179 0.9962046146392822
# Loss and prediction by the model after 1880000 steps of gradient descent are 1.034449577331543 0.9962064623832703
# Loss and prediction by the model after 1890000 steps of gradient descent are 1.0342305898666382 0.9962079524993896
# Loss and prediction by the model after 1900000 steps of gradient descent are 1.0340142250061035 0.9962092638015747
# Loss and prediction by the model after 1910000 steps of gradient descent are 1.0338006019592285 0.9962105751037598
# Loss and prediction by the model after 1920000 steps of gradient descent are 1.033589243888855 0.9962119460105896
# Loss and prediction by the model after 1930000 steps of gradient descent are 1.0333808660507202 0.9962134957313538
# Loss and prediction by the model after 1940000 steps of gradient descent are 1.0331751108169556 0.9962146878242493
# Loss and prediction by the model after 1950000 steps of gradient descent are 1.032971739768982 0.9962159395217896
# Loss and prediction by the model after 1960000 steps of gradient descent are 1.0327706336975098 0.996216893196106
# Loss and prediction by the model after 1970000 steps of gradient descent are 1.0325719118118286 0.9962184429168701
# Loss and prediction by the model after 1980000 steps of gradient descent are 1.0323760509490967 0.9962201118469238
# Loss and prediction by the model after 1990000 steps of gradient descent are 1.0321825742721558 0.996221661567688

# %%
plt.imshow(imagef.detach().cpu().numpy().reshape(28,28))

# %%
plt.imshow(diff.detach().cpu().numpy().reshape(28,28))

# %%
learning_rate=0.0005
num_descents=4000000 #number of times gradient descent is employed

img=img.cuda()

for i in range(2000000,num_descents):
    
    imagef=img+diff
    pred=torch.exp(model(imagef.reshape([1,784])))[0][8]
    
    totalloss=findloss(diff,pred)
    if i%10000 ==0:
        print('Loss and prediction by the model after '+str(i)+' steps of gradient descent are '+str(totalloss.item()),str(pred.item()))
     
        
    #find gradients of totalt wrt yarray.
    totalloss.backward()

    gradients=diff.grad
    #torch.clip(gradients,max=100.0)
    with torch.no_grad():
        diff[1:]=diff[1:]-learning_rate*gradients[1:]
    diff.grad.data.zero_()
# Out:
# Loss and prediction by the model after 2000000 steps of gradient descent are 1.0319912433624268 0.9962232112884521
# Loss and prediction by the model after 2010000 steps of gradient descent are 1.0318021774291992 0.9962248802185059
# Loss and prediction by the model after 2020000 steps of gradient descent are 1.0316153764724731 0.9962263107299805
# Loss and prediction by the model after 2030000 steps of gradient descent are 1.0314306020736694 0.9962276816368103
# Loss and prediction by the model after 2040000 steps of gradient descent are 1.0312479734420776 0.996229350566864
# Loss and prediction by the model after 2050000 steps of gradient descent are 1.0310677289962769 0.9962306618690491
# Loss and prediction by the model after 2060000 steps of gradient descent are 1.0308893918991089 0.9962320327758789
# Loss and prediction by the model after 2070000 steps of gradient descent are 1.0307132005691528 0.996233344078064
# Loss and prediction by the model after 2080000 steps of gradient descent are 1.03053879737854 0.9962349534034729
# Loss and prediction by the model after 2090000 steps of gradient descent are 1.0303666591644287 0.996236264705658
# Loss and prediction by the model after 2100000 steps of gradient descent are 1.0301965475082397 0.9962371587753296
# Loss and prediction by the model after 2110000 steps of gradient descent are 1.0300287008285522 0.9962378740310669
# Loss and prediction by the model after 2120000 steps of gradient descent are 1.0298629999160767 0.9962387084960938
# Loss and prediction by the model after 2130000 steps of gradient descent are 1.0296990871429443 0.9962400197982788
# Loss and prediction by the model after 2140000 steps of gradient descent are 1.0295372009277344 0.9962414503097534
# Loss and prediction by the model after 2150000 steps of gradient descent are 1.0293772220611572 0.9962425827980042
# Loss and prediction by the model after 2160000 steps of gradient descent are 1.0292192697525024 0.9962436556816101
# Loss and prediction by the model after 2170000 steps of gradient descent are 1.0290629863739014 0.996244490146637
# Loss and prediction by the model after 2180000 steps of gradient descent are 1.0289087295532227 0.9962452054023743
# Loss and prediction by the model after 2190000 steps of gradient descent are 1.0287559032440186 0.9962460994720459
# Loss and prediction by the model after 2200000 steps of gradient descent are 1.0286049842834473 0.9962467551231384
# Loss and prediction by the model after 2210000 steps of gradient descent are 1.0284558534622192 0.996247410774231
# Loss and prediction by the model after 2220000 steps of gradient descent are 1.0283082723617554 0.9962484240531921
# Loss and prediction by the model after 2230000 steps of gradient descent are 1.0281625986099243 0.9962494969367981
# Loss and prediction by the model after 2240000 steps of gradient descent are 1.028018832206726 0.996250331401825
# Loss and prediction by the model after 2250000 steps of gradient descent are 1.0278769731521606 0.9962512254714966
# Loss and prediction by the model after 2260000 steps of gradient descent are 1.027736783027649 0.9962520599365234
# Loss and prediction by the model after 2270000 steps of gradient descent are 1.0275981426239014 0.9962530136108398
# Loss and prediction by the model after 2280000 steps of gradient descent are 1.027461290359497 0.9962543249130249
# Loss and prediction by the model after 2290000 steps of gradient descent are 1.027326226234436 0.9962555170059204
# Loss and prediction by the model after 2300000 steps of gradient descent are 1.0271925926208496 0.9962570667266846
# Loss and prediction by the model after 2310000 steps of gradient descent are 1.0270607471466064 0.9962581992149353
# Loss and prediction by the model after 2320000 steps of gradient descent are 1.026930332183838 0.9962593913078308
# Loss and prediction by the model after 2330000 steps of gradient descent are 1.0268018245697021 0.9962604641914368
# Loss and prediction by the model after 2340000 steps of gradient descent are 1.0266748666763306 0.9962616562843323
# Loss and prediction by the model after 2350000 steps of gradient descent are 1.0265493392944336 0.9962627291679382
# Loss and prediction by the model after 2360000 steps of gradient descent are 1.0264254808425903 0.9962639212608337
# Loss and prediction by the model after 2370000 steps of gradient descent are 1.0263030529022217 0.9962650537490845
# Loss and prediction by the model after 2380000 steps of gradient descent are 1.0261820554733276 0.9962660670280457
# Loss and prediction by the model after 2390000 steps of gradient descent are 1.0260626077651978 0.9962671399116516
# Loss and prediction by the model after 2400000 steps of gradient descent are 1.0259445905685425 0.9962681531906128
# Loss and prediction by the model after 2410000 steps of gradient descent are 1.0258280038833618 0.9962691068649292
# Loss and prediction by the model after 2420000 steps of gradient descent are 1.0257126092910767 0.9962700605392456
# Loss and prediction by the model after 2430000 steps of gradient descent are 1.0255990028381348 0.9962707161903381
# Loss and prediction by the model after 2440000 steps of gradient descent are 1.0254865884780884 0.9962717890739441
# Loss and prediction by the model after 2450000 steps of gradient descent are 1.0253756046295166 0.9962724447250366
# Loss and prediction by the model after 2460000 steps of gradient descent are 1.0252659320831299 0.9962732791900635
# Loss and prediction by the model after 2470000 steps of gradient descent are 1.0251575708389282 0.996273934841156
# Loss and prediction by the model after 2480000 steps of gradient descent are 1.0250506401062012 0.9962747693061829
# Loss and prediction by the model after 2490000 steps of gradient descent are 1.0249450206756592 0.9962758421897888
# Loss and prediction by the model after 2500000 steps of gradient descent are 1.0248404741287231 0.9962767958641052
# Loss and prediction by the model after 2510000 steps of gradient descent are 1.0247373580932617 0.9962778687477112
# Loss and prediction by the model after 2520000 steps of gradient descent are 1.0246354341506958 0.9962789416313171
# Loss and prediction by the model after 2530000 steps of gradient descent are 1.024534821510315 0.996279776096344
# Loss and prediction by the model after 2540000 steps of gradient descent are 1.0244356393814087 0.9962804317474365
# Loss and prediction by the model after 2550000 steps of gradient descent are 1.0243375301361084 0.9962816834449768
# Loss and prediction by the model after 2560000 steps of gradient descent are 1.0242406129837036 0.9962830543518066
# Loss and prediction by the model after 2570000 steps of gradient descent are 1.0241450071334839 0.9962844252586365
# Loss and prediction by the model after 2580000 steps of gradient descent are 1.0240505933761597 0.9962857365608215
# Loss and prediction by the model after 2590000 steps of gradient descent are 1.0239574909210205 0.9962866902351379
# Loss and prediction by the model after 2600000 steps of gradient descent are 1.0238653421401978 0.9962877035140991
# Loss and prediction by the model after 2610000 steps of gradient descent are 1.0237743854522705 0.9962885975837708
# Loss and prediction by the model after 2620000 steps of gradient descent are 1.0236845016479492 0.9962893724441528
# Loss and prediction by the model after 2630000 steps of gradient descent are 1.0235955715179443 0.9962899088859558
# Loss and prediction by the model after 2640000 steps of gradient descent are 1.0235077142715454 0.9962905049324036
# Loss and prediction by the model after 2650000 steps of gradient descent are 1.023420810699463 0.9962907433509827
# Loss and prediction by the model after 2660000 steps of gradient descent are 1.0233349800109863 0.9962909817695618
# Loss and prediction by the model after 2670000 steps of gradient descent are 1.0232501029968262 0.9962913990020752
# Loss and prediction by the model after 2680000 steps of gradient descent are 1.0231660604476929 0.9962918162345886
# Loss and prediction by the model after 2690000 steps of gradient descent are 1.0230830907821655 0.9962920546531677
# Loss and prediction by the model after 2700000 steps of gradient descent are 1.0230010747909546 0.9962922930717468
# Loss and prediction by the model after 2710000 steps of gradient descent are 1.0229201316833496 0.9962922930717468
# Loss and prediction by the model after 2720000 steps of gradient descent are 1.0228402614593506 0.996292233467102
# Loss and prediction by the model after 2730000 steps of gradient descent are 1.0227612257003784 0.996291995048523
# Loss and prediction by the model after 2740000 steps of gradient descent are 1.0226832628250122 0.9962920546531677
# Loss and prediction by the model after 2750000 steps of gradient descent are 1.0226062536239624 0.9962920546531677
# Loss and prediction by the model after 2760000 steps of gradient descent are 1.0225300788879395 0.996292233467102
# Loss and prediction by the model after 2770000 steps of gradient descent are 1.0224549770355225 0.9962926506996155
# Loss and prediction by the model after 2780000 steps of gradient descent are 1.0223809480667114 0.9962931275367737
# Loss and prediction by the model after 2790000 steps of gradient descent are 1.0223077535629272 0.9962936043739319
# Loss and prediction by the model after 2800000 steps of gradient descent are 1.02223539352417 0.9962942004203796
# Loss and prediction by the model after 2810000 steps of gradient descent are 1.0221641063690186 0.9962946772575378
# Loss and prediction by the model after 2820000 steps of gradient descent are 1.0220937728881836 0.9962952733039856
# Loss and prediction by the model after 2830000 steps of gradient descent are 1.022024154663086 0.9962961077690125
# Loss and prediction by the model after 2840000 steps of gradient descent are 1.0219554901123047 0.9962969422340393
# Loss and prediction by the model after 2850000 steps of gradient descent are 1.0218875408172607 0.9962974786758423
# Loss and prediction by the model after 2860000 steps of gradient descent are 1.021820306777954 0.99629807472229
# Loss and prediction by the model after 2870000 steps of gradient descent are 1.0217540264129639 0.9962987899780273
# Loss and prediction by the model after 2880000 steps of gradient descent are 1.0216885805130005 0.9962993860244751
# Loss and prediction by the model after 2890000 steps of gradient descent are 1.021623969078064 0.9963001012802124
# Loss and prediction by the model after 2900000 steps of gradient descent are 1.0215601921081543 0.9963006973266602
# Loss and prediction by the model after 2910000 steps of gradient descent are 1.0214972496032715 0.9963011741638184
# Loss and prediction by the model after 2920000 steps of gradient descent are 1.021435022354126 0.9963017106056213
# Loss and prediction by the model after 2930000 steps of gradient descent are 1.0213736295700073 0.9963021278381348
# Loss and prediction by the model after 2940000 steps of gradient descent are 1.0213128328323364 0.996302604675293
# Loss and prediction by the model after 2950000 steps of gradient descent are 1.021252989768982 0.9963029026985168
# Loss and prediction by the model after 2960000 steps of gradient descent are 1.0211937427520752 0.9963035583496094
# Loss and prediction by the model after 2970000 steps of gradient descent are 1.0211350917816162 0.9963039755821228
# Loss and prediction by the model after 2980000 steps of gradient descent are 1.021077275276184 0.9963047504425049
# Loss and prediction by the model after 2990000 steps of gradient descent are 1.0210201740264893 0.9963052868843079
# Loss and prediction by the model after 3000000 steps of gradient descent are 1.0209636688232422 0.9963061213493347
# Loss and prediction by the model after 3010000 steps of gradient descent are 1.0209078788757324 0.9963069558143616
# Loss and prediction by the model after 3020000 steps of gradient descent are 1.02085280418396 0.9963076710700989
# Loss and prediction by the model after 3030000 steps of gradient descent are 1.0207983255386353 0.996308445930481
# Loss and prediction by the model after 3040000 steps of gradient descent are 1.020744800567627 0.9963088631629944
# Loss and prediction by the model after 3050000 steps of gradient descent are 1.0206917524337769 0.9963092803955078
# Loss and prediction by the model after 3060000 steps of gradient descent are 1.0206393003463745 0.9963098168373108
# Loss and prediction by the model after 3070000 steps of gradient descent are 1.020587682723999 0.9963101744651794
# Loss and prediction by the model after 3080000 steps of gradient descent are 1.0205367803573608 0.9963104128837585
# Loss and prediction by the model after 3090000 steps of gradient descent are 1.0204862356185913 0.9963108897209167
# Loss and prediction by the model after 3100000 steps of gradient descent are 1.0204366445541382 0.9963110089302063
# Loss and prediction by the model after 3110000 steps of gradient descent are 1.0203875303268433 0.9963112473487854
# Loss and prediction by the model after 3120000 steps of gradient descent are 1.020339012145996 0.9963117241859436
# Loss and prediction by the model after 3130000 steps of gradient descent are 1.0202910900115967 0.9963119626045227
# Loss and prediction by the model after 3140000 steps of gradient descent are 1.0202436447143555 0.9963123202323914
# Loss and prediction by the model after 3150000 steps of gradient descent are 1.020196795463562 0.9963126182556152
# Loss and prediction by the model after 3160000 steps of gradient descent are 1.0201505422592163 0.9963128566741943
# Loss and prediction by the model after 3170000 steps of gradient descent are 1.0201048851013184 0.9963131546974182
# Loss and prediction by the model after 3180000 steps of gradient descent are 1.0200597047805786 0.9963134527206421
# Loss and prediction by the model after 3190000 steps of gradient descent are 1.0200151205062866 0.9963139295578003
# Loss and prediction by the model after 3200000 steps of gradient descent are 1.0199710130691528 0.996314525604248
# Loss and prediction by the model after 3210000 steps of gradient descent are 1.0199273824691772 0.9963149428367615
# Loss and prediction by the model after 3220000 steps of gradient descent are 1.0198843479156494 0.9963153600692749
# Loss and prediction by the model after 3230000 steps of gradient descent are 1.0198420286178589 0.9963153600692749
# Loss and prediction by the model after 3240000 steps of gradient descent are 1.0197999477386475 0.9963157773017883
# Loss and prediction by the model after 3250000 steps of gradient descent are 1.0197584629058838 0.9963160157203674
# Loss and prediction by the model after 3260000 steps of gradient descent are 1.0197175741195679 0.9963161945343018
# Loss and prediction by the model after 3270000 steps of gradient descent are 1.0196771621704102 0.9963164329528809
# Loss and prediction by the model after 3280000 steps of gradient descent are 1.0196373462677002 0.9963164329528809
# Loss and prediction by the model after 3290000 steps of gradient descent are 1.0195978879928589 0.9963166117668152
# Loss and prediction by the model after 3300000 steps of gradient descent are 1.0195589065551758 0.9963168501853943
# Loss and prediction by the model after 3310000 steps of gradient descent are 1.0195204019546509 0.9963170289993286
# Loss and prediction by the model after 3320000 steps of gradient descent are 1.0194823741912842 0.9963171482086182
# Loss and prediction by the model after 3330000 steps of gradient descent are 1.0194449424743652 0.9963172674179077
# Loss and prediction by the model after 3340000 steps of gradient descent are 1.0194079875946045 0.9963171482086182
# Loss and prediction by the model after 3350000 steps of gradient descent are 1.0193712711334229 0.9963172674179077
# Loss and prediction by the model after 3360000 steps of gradient descent are 1.0193350315093994 0.9963171482086182
# Loss and prediction by the model after 3370000 steps of gradient descent are 1.0192993879318237 0.9963172674179077
# Loss and prediction by the model after 3380000 steps of gradient descent are 1.0192642211914062 0.9963172674179077
# Loss and prediction by the model after 3390000 steps of gradient descent are 1.0192294120788574 0.9963173866271973
# Loss and prediction by the model after 3400000 steps of gradient descent are 1.0191950798034668 0.9963172674179077
# Loss and prediction by the model after 3410000 steps of gradient descent are 1.0191609859466553 0.9963173866271973
# Loss and prediction by the model after 3420000 steps of gradient descent are 1.0191274881362915 0.9963171482086182
# Loss and prediction by the model after 3430000 steps of gradient descent are 1.019094467163086 0.9963170289993286
# Loss and prediction by the model after 3440000 steps of gradient descent are 1.0190616846084595 0.9963170289993286
# Loss and prediction by the model after 3450000 steps of gradient descent are 1.0190293788909912 0.9963169097900391
# Loss and prediction by the model after 3460000 steps of gradient descent are 1.0189975500106812 0.9963166117668152
# Loss and prediction by the model after 3470000 steps of gradient descent are 1.0189659595489502 0.9963166117668152
# Loss and prediction by the model after 3480000 steps of gradient descent are 1.018934965133667 0.9963163733482361
# Loss and prediction by the model after 3490000 steps of gradient descent are 1.0189040899276733 0.9963163733482361
# Loss and prediction by the model after 3500000 steps of gradient descent are 1.018873691558838 0.9963161945343018
# Loss and prediction by the model after 3510000 steps of gradient descent are 1.0188437700271606 0.9963160157203674
# Loss and prediction by the model after 3520000 steps of gradient descent are 1.018814206123352 0.9963157773017883
# Loss and prediction by the model after 3530000 steps of gradient descent are 1.0187848806381226 0.996315598487854
# Loss and prediction by the model after 3540000 steps of gradient descent are 1.0187560319900513 0.9963153600692749
# Loss and prediction by the model after 3550000 steps of gradient descent are 1.018727421760559 0.9963153004646301
# Loss and prediction by the model after 3560000 steps of gradient descent are 1.018699288368225 0.9963153004646301
# Loss and prediction by the model after 3570000 steps of gradient descent are 1.0186713933944702 0.9963153004646301
# Loss and prediction by the model after 3580000 steps of gradient descent are 1.018644094467163 0.9963153004646301
# Loss and prediction by the model after 3590000 steps of gradient descent are 1.018617033958435 0.9963153004646301
# Loss and prediction by the model after 3600000 steps of gradient descent are 1.0185903310775757 0.9963153004646301
# Loss and prediction by the model after 3610000 steps of gradient descent are 1.018563985824585 0.9963151216506958
# Loss and prediction by the model after 3620000 steps of gradient descent are 1.0185378789901733 0.9963150024414062
# Loss and prediction by the model after 3630000 steps of gradient descent are 1.0185121297836304 0.9963149428367615
# Loss and prediction by the model after 3640000 steps of gradient descent are 1.018486738204956 0.9963147044181824
# Loss and prediction by the model after 3650000 steps of gradient descent are 1.0184614658355713 0.996314525604248
# Loss and prediction by the model after 3660000 steps of gradient descent are 1.0184366703033447 0.996314287185669
# Loss and prediction by the model after 3670000 steps of gradient descent are 1.0184121131896973 0.9963141083717346
# Loss and prediction by the model after 3680000 steps of gradient descent are 1.018387794494629 0.9963138699531555
# Loss and prediction by the model after 3690000 steps of gradient descent are 1.0183639526367188 0.9963136911392212
# Loss and prediction by the model after 3700000 steps of gradient descent are 1.0183403491973877 0.9963136315345764
# Loss and prediction by the model after 3710000 steps of gradient descent are 1.0183169841766357 0.9963134527206421
# Loss and prediction by the model after 3720000 steps of gradient descent are 1.018293857574463 0.9963134527206421
# Loss and prediction by the model after 3730000 steps of gradient descent are 1.0182710886001587 0.9963133931159973
# Loss and prediction by the model after 3740000 steps of gradient descent are 1.0182485580444336 0.996313214302063
# Loss and prediction by the model after 3750000 steps of gradient descent are 1.0182262659072876 0.9963131546974182
# Loss and prediction by the model after 3760000 steps of gradient descent are 1.0182043313980103 0.9963133931159973
# Loss and prediction by the model after 3770000 steps of gradient descent are 1.0181825160980225 0.9963136315345764
# Loss and prediction by the model after 3780000 steps of gradient descent are 1.0181612968444824 0.9963136315345764
# Loss and prediction by the model after 3790000 steps of gradient descent are 1.0181399583816528 0.9963138699531555
# Loss and prediction by the model after 3800000 steps of gradient descent are 1.018119215965271 0.9963136911392212
# Loss and prediction by the model after 3810000 steps of gradient descent are 1.0180984735488892 0.9963138699531555
# Loss and prediction by the model after 3820000 steps of gradient descent are 1.018078088760376 0.9963138699531555
# Loss and prediction by the model after 3830000 steps of gradient descent are 1.018057942390442 0.9963141083717346
# Loss and prediction by the model after 3840000 steps of gradient descent are 1.0180381536483765 0.9963139295578003
# Loss and prediction by the model after 3850000 steps of gradient descent are 1.018018364906311 0.9963139295578003
# Loss and prediction by the model after 3860000 steps of gradient descent are 1.0179990530014038 0.9963138699531555
# Loss and prediction by the model after 3870000 steps of gradient descent are 1.0179798603057861 0.9963136315345764
# Loss and prediction by the model after 3880000 steps of gradient descent are 1.017960786819458 0.9963136911392212
# Loss and prediction by the model after 3890000 steps of gradient descent are 1.017942190170288 0.9963136315345764
# Loss and prediction by the model after 3900000 steps of gradient descent are 1.0179237127304077 0.9963136315345764
# Loss and prediction by the model after 3910000 steps of gradient descent are 1.0179054737091064 0.9963134527206421
# Loss and prediction by the model after 3920000 steps of gradient descent are 1.0178874731063843 0.996313214302063
# Loss and prediction by the model after 3930000 steps of gradient descent are 1.0178695917129517 0.996313214302063
# Loss and prediction by the model after 3940000 steps of gradient descent are 1.0178519487380981 0.9963131546974182
# Loss and prediction by the model after 3950000 steps of gradient descent are 1.0178345441818237 0.9963131546974182
# Loss and prediction by the model after 3960000 steps of gradient descent are 1.017817497253418 0.9963130354881287
# Loss and prediction by the model after 3970000 steps of gradient descent are 1.0178005695343018 0.9963130354881287
# Loss and prediction by the model after 3980000 steps of gradient descent are 1.017783761024475 0.9963131546974182
# Loss and prediction by the model after 3990000 steps of gradient descent are 1.0177671909332275 0.996313214302063

# %%
plt.imshow(imagef.detach().cpu().numpy().reshape(28,28))

# %%
plt.imshow(diff.detach().cpu().numpy().reshape(28,28))
