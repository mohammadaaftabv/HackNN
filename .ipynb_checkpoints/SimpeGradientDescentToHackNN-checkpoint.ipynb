# %%
import torch

#imports necessary to define a neural network 
import torch.nn as nn
import torch.nn.functional as F

#ensure you are using GPU.
if torch.cuda.is_available():  
  dev = "cuda:0" 
else:  
  dev = "cpu"  

device = torch.device(dev)
print(device)

dtype = torch.cuda.FloatTensor
import numpy as np
import torchvision
import matplotlib.pyplot as plt
from time import time
from torchvision import datasets, transforms
from torch import nn, optim
# Out:
# cuda:0

# %%
transform = transforms.Compose([transforms.ToTensor()])

# %%
trainset = datasets.MNIST('PATH_TO_STORE_TRAINSET', download=True, train=True, transform=transform)
valset = datasets.MNIST('PATH_TO_STORE_TESTSET', download=True, train=False, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=64, shuffle=True)
# Out:
# /home/mohammad/anaconda3/lib/python3.8/site-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1631630815121/work/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
dataiter = iter(trainloader)
images, labels = dataiter.next()

print(images.shape)
print(labels.shape)
# Out:
# torch.Size([64, 1, 28, 28])
# torch.Size([64])

# %%
figure = plt.figure()
num_of_images = 60
for index in range(1, num_of_images + 1):
    plt.subplot(6, 10, index)
    plt.axis('off')
    plt.imshow(images[index].numpy().squeeze(), cmap='gray_r')

# %%
input_size = 784
hidden_sizes = [128, 64]
output_size = 10

model = nn.Sequential(nn.Linear(input_size, hidden_sizes[0]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[0], hidden_sizes[1]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[1], output_size),
                      nn.LogSoftmax()).cuda()
model.to(device)
print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=64, out_features=10, bias=True)
#   (5): LogSoftmax(dim=None)
# )

# %%
criterion = nn.NLLLoss()
images, labels = next(iter(trainloader))
images = images.view(images.shape[0], -1)

logps = model(images.cuda()) #log probabilities
loss = criterion(logps, labels.cuda()) #calculate the NLL loss
# Out:
# /home/mohammad/anaconda3/lib/python3.8/site-packages/torch/nn/modules/container.py:139: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)

# %%
optimizer = optim.SGD(model.parameters(), lr=0.003, momentum=0.9)
time0 = time()
epochs = 15
for e in range(epochs):
    running_loss = 0
    for images, labels in trainloader:
        # Flatten MNIST images into a 784 long vector
        images = images.view(images.shape[0], -1)
    
        # Training pass
        optimizer.zero_grad()
        
        output = model(images.cuda())
        loss = criterion(output, labels.cuda())
        
        #This is where the model learns by backpropagating
        loss.backward()
        
        #And optimizes its weights here
        optimizer.step()
        
        running_loss += loss.item()
    else:
        print("Epoch {} - Training loss: {}".format(e, running_loss/len(trainloader)))
        print("\nTraining Time (in minutes) =",(time()-time0)/60)
# Out:
# Epoch 0 - Training loss: 0.9350218173029072
#
# Training Time (in minutes) = 0.06174592971801758
# Epoch 1 - Training loss: 0.33955660560873274
#
# Training Time (in minutes) = 0.12254387935002645
# Epoch 2 - Training loss: 0.278805788248968
#
# Training Time (in minutes) = 0.1816303332646688
# Epoch 3 - Training loss: 0.2358408801670649
#
# Training Time (in minutes) = 0.24157983859380086
# Epoch 4 - Training loss: 0.20078633627149342
#
# Training Time (in minutes) = 0.30295567512512206
# Epoch 5 - Training loss: 0.17267264138414726
#
# Training Time (in minutes) = 0.36151047150293986
# Epoch 6 - Training loss: 0.1511120536664465
#
# Training Time (in minutes) = 0.42177145878473915
# Epoch 7 - Training loss: 0.134448580511375
#
# Training Time (in minutes) = 0.48378449281056723
# Epoch 8 - Training loss: 0.12026490895018013
#
# Training Time (in minutes) = 0.5456776738166809
# Epoch 9 - Training loss: 0.10874154304525555
#
# Training Time (in minutes) = 0.6060248374938965
# Epoch 10 - Training loss: 0.09818324255747105
#
# Training Time (in minutes) = 0.6660294731458029
# Epoch 11 - Training loss: 0.09012734945982631
#
# Training Time (in minutes) = 0.727437142531077
# Epoch 12 - Training loss: 0.0823370824004017
#
# Training Time (in minutes) = 0.7871309677759807
# Epoch 13 - Training loss: 0.07579991316645225
#
# Training Time (in minutes) = 0.846235473950704
# Epoch 14 - Training loss: 0.06987406905573695
#
# Training Time (in minutes) = 0.9093520601590475

# %%
def view_classify(img, ps):
    ''' Function for viewing an image and it's predicted classes.
    '''
    ps = ps.cpu().data.numpy().squeeze()

    fig, (ax1, ax2) = plt.subplots(figsize=(6,9), ncols=2)
    ax1.imshow(img.resize_(1, 28, 28).numpy().squeeze())
    ax1.axis('off')
    ax2.barh(np.arange(10), ps)
    ax2.set_aspect(0.1)
    ax2.set_yticks(np.arange(10))
    ax2.set_yticklabels(np.arange(10))
    ax2.set_title('Class Probability')
    ax2.set_xlim(0, 1.1)
    plt.tight_layout()
images, labels = next(iter(valloader))

img = images[0].view(1, 784) 
with torch.no_grad():
    logps = model(img.cuda())

ps = torch.exp(logps)
probab = list(ps.detach().cpu().numpy()[0])
print("Predicted Digit =", probab.index(max(probab)))
view_classify(img.view(1, 28, 28), ps)
# Out:
# Predicted Digit = 9

# %%
torch.exp(model(img.cuda()))
# Out:
# tensor([[3.2078e-06, 7.1268e-05, 9.2187e-06, 1.1592e-03, 1.7327e-01, 1.6017e-04,
#          8.6960e-07, 4.2616e-03, 2.6383e-03, 8.1843e-01]], device='cuda:0',
#        grad_fn=<ExpBackward>)

# %%
correct_count, all_count = 0, 0
for images,labels in valloader:
  for i in range(len(labels)):
    img = images[i].view(1, 784)
    with torch.no_grad():
        logps = model(img.cuda())

    
    ps = torch.exp(logps)
    probab = list(ps.detach().cpu().numpy()[0])
    pred_label = probab.index(max(probab))
    true_label = labels.numpy()[i]
    if(true_label == pred_label):
      correct_count += 1
    all_count += 1

print("Number Of Images Tested =", all_count)
print("\nModel Accuracy =", (correct_count/all_count))
# Out:
# Number Of Images Tested = 10000
#
# Model Accuracy = 0.9734

# %%
images.shape
# Out:
# torch.Size([16, 1, 28, 28])

# %%
img=images[4].reshape([1,784])
print(img.shape)

print(torch.exp(model(img.cuda())))
plt.imshow(img.numpy().reshape(28,28))
# Out:
# torch.Size([1, 784])
# tensor([[6.2905e-07, 2.1308e-10, 5.4840e-09, 1.0438e-08, 9.9609e-01, 5.1524e-06,
#          8.7961e-05, 1.3981e-06, 3.0068e-03, 8.0396e-04]], device='cuda:0',
#        grad_fn=<ExpBackward>)

# %%
def findloss(origimg,img,pred):
    
#     img is array of new image
#     pred is the prediction of the above trained model
    
    l1=(torch.square(img - origimg))
    l1=torch.mean(l1)
    l2=pred**(-2)/100000.0
    
    fl=l1+l2
    fl=fl**0.5
    
    return fl

# %%
imagef=torch.rand(784).cuda().requires_grad_()

# %%
learning_rate=0.0005
num_descents=2000000 #number of times gradient descent is employed


for i in range(num_descents):
    
    pred=torch.exp(model(imagef.reshape([1,784])))[0][4]
    totalt=findloss(img.cuda(),imagef,pred)
    if i%10000 ==0:
        print(totalt,pred)
    #find gradients of totalt wrt yarray.
    totalt.backward()

    gradients=imagef.grad
    #update ysol in array
    with torch.no_grad():
        #update all y values except initial and final states
        imagef[1:-1]=imagef[1:-1]-learning_rate*gradients[1:-1]
    imagef.grad.data.zero_()
# Out:
# tensor(14696547., device='cuda:0', grad_fn=<PowBackward0>) tensor(2.1517e-09, device='cuda:0', grad_fn=<SelectBackward>)
# tensor(nan, device='cuda:0', grad_fn=<PowBackward0>) tensor(nan, device='cuda:0', grad_fn=<SelectBackward>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-e4fd64cba580> in <module>
#       6
#       7     pred=torch.exp(model(imagef.reshape([1,784])))[0][4]
# ----> 8     totalt=findloss(img.cuda(),imagef,pred)
#       9     if i%10000 ==0:
#      10         print(totalt,pred)
#
# <ipython-input-22-42b738f0d11f> in findloss(origimg, img, pred)
#       9
#      10     fl=l1+l2
# ---> 11     fl=fl**0.5
#      12
#      13     return fl
#
# KeyboardInterrupt:

# %%
plt.imshow(imagef.detach().cpu().numpy().reshape(28,28))

# %%
plt.imshow(img.reshape(28,28))
